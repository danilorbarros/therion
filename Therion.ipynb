# %%
import Therion as t

therion = t.Therion()

# %%
therion.get_therion_list()
therion.get_prices('card')
# Out:
# Jasmine (link) no valor de, R$ 23,85
# Ventos secos no valor de, R$ 99,99
# Dharc (link) no valor de, R$ 15,00
# Primula no valor de, R$ 3,99

# %%
therion.heathcote()

# %%
therion.dragonstone()

# %%
therion.dragonstones()
