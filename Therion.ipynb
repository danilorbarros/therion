# %%
import Therion as t

therion = t.Therion()

# %%
therion.get_therion_list()
therion.get_prices('card')
# Out:
# Jasmine (link) no valor de, R$ 24,99
# Ventos secos no valor de, R$ 99,99
# Dharc (link) no valor de, R$ 18,98
# Solemn Wishes no valor de, R$ 0,00

# %%
therion.heathcote()

# %%
therion.dragonstone()

# %%
therion.dragonstones()
